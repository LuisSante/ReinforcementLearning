# %%
import numpy as np

file_names = 'training_scores_history.npy' 

try:
    data = np.load(file_names)
    
    print(f"File '{file_names}' loaded successfully.")
    
    print(f"Data type: {data.dtype}")
    print(f"Shape: {data.shape}")
    print(f"Dimensions: {data.ndim}")
    
    print(data)

except FileNotFoundError:
    print(f"Error'{file_names}' not found.")
except Exception as e:
    print(f"Error {e}")
# Out:
# File 'training_scores_history.npy' loaded successfully.
# Data type: float64
# Shape: (200,)
# Dimensions: 1
# [ -81.72980216  -86.24042352  -95.93289273 -105.46880097 -102.52765589
#  -102.48436949 -100.47837828 -109.86139903  -87.23925278  -81.08179803
#   -80.23425051  -83.56045965  -76.13191994  -74.30994456  -82.65635761
#  -115.73409491 -121.1896559  -118.03708965  -84.07276938  -89.85311021
#   -96.89376369  -84.73368575  -85.72311088  -78.33888683  -59.73714332
#   -76.33635061 -109.60730773  -51.37221558  -81.9349477   -50.86918597
#   -51.59376724  -55.01178293  -46.81579079  -52.34910205  -45.36163564
#  -105.08188031 -102.50558524  -88.08948157  -50.59165432  -60.79410678
#   -42.6794555   -54.68593347  -54.71246378  -59.38138385  -51.77505293
#   -44.01692832  -43.29497556  -42.46672115  -44.63026225  -60.59405102
#   -44.09081331  -43.52435018  -46.86745718  -66.11937562  -45.68440778
#   -44.02522663 -110.18526646  -67.2107143   -62.12101842  -55.17270247
# ...
